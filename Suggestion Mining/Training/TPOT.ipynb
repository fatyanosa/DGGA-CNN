# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import timeit
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split
import numpy as np
from os import path
import csv
# Out:
# /lab/dbms/fatyanosa/.userprogram/anaconda3/envs/GA-CNN/lib/python3.7/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %%
class utility:

    def append_df_to_excel(self, df, excel_path):
        if path.isfile(excel_path):
            df_excel = pd.read_excel(excel_path)
            result = pd.concat([df_excel, df], ignore_index=True)
            result.to_excel(excel_path, index=False)
        else:
            df.to_excel(excel_path, index=False)

    def read_CSV(self, filename):
        df = pd.read_csv(filename)
        return df

    def get_text_label(self, df):
        texts = []  # list of text samples
        labels = []  # list of label ids
        for index, row in df.iterrows():
            if isinstance(row['sentence'], float):
                texts.append(str(row['sentence']))
            else:
                texts.append(row['sentence'])

            labels.append(row['label'])

        return texts, labels

    def tokenize_texts(self, texts):
        tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=10000)
        tokenizer.fit_on_texts(texts)

        return tokenizer

    def padding_texts(self, texts, maxlen):

        texts = tf.keras.preprocessing.sequence.pad_sequences(texts, padding='post', maxlen=maxlen)

        return texts

    def get_testing_metric(self, y_test, y_pred):
        accuracyScore = accuracy_score(y_test, y_pred)
        precisionScore= precision_score(y_test, y_pred)
        recallScore = recall_score(y_test, y_pred)
        f1Score = f1_score(y_test, y_pred)

        return accuracyScore, precisionScore, recallScore, f1Score

    def write_df_csv(self, df, out_path):
        df.to_csv(out_path, index=False)

    def create_embedding_matrix(self, filepath, word_index, embedding_dim):
        vocab_size = len(word_index) + 1  # Adding again 1 because of reserved 0 index
        embedding_matrix = np.zeros((vocab_size, embedding_dim))

        with open(filepath, encoding="utf8") as f:
            for line in f:
                word, *vector = line.split()
                if word in word_index:
                    idx = word_index[word]
                    embedding_matrix[idx] = np.array(
                        vector, dtype=np.float32)[:embedding_dim]

        return embedding_matrix

    def get_max_length_of_sentences(self, texts):
        maxlength = 0
        for text in texts:
            if (len(text.split()) > maxlength):
                maxlength = len(text.split())

        return maxlength

    def get_training_trial_data(self, textsTraining, textsTrial, labelsTraining, labelsTrial):
        textsTraining, textsTesting = np.asarray(textsTraining), np.asarray(textsTrial)
        y_train, y_val = np.asarray(labelsTraining), np.asarray(labelsTrial)

        # Tokenize words
        tokenizer = self.tokenize_texts(textsTraining)
        X_train = tokenizer.texts_to_sequences(textsTraining)
        X_val = tokenizer.texts_to_sequences(textsTesting)

        # Adding 1 because of reserved 0 index
        vocab_size = len(tokenizer.word_index) + 1

        # get maxlen
        maxlen = self.get_max_length_of_sentences(textsTraining)

        # Pad sequences with zeros
        X_train = self.padding_texts(X_train, maxlen)
        X_val = self.padding_texts(X_val, maxlen)
        
        return X_train, X_val, y_train, y_val

    def get_X_Y_data(self, textsTraining, labelsTraining):
        textsTraining = np.asarray(textsTraining)
        y_train = np.asarray(labelsTraining)

        # Tokenize words
        tokenizer = self.tokenize_texts(textsTraining)
        X_train = tokenizer.texts_to_sequences(textsTraining)

        # Adding 1 because of reserved 0 index
        vocab_size = len(tokenizer.word_index) + 1

        # get maxlen
        maxlen = self.get_max_length_of_sentences(textsTraining)

        # Pad sequences with zeros
        X_train = self.padding_texts(X_train, maxlen)

        return X_train, y_train

    def Average(self, list):
        return sum(list) / len(list)
    
    def recall_m(self, y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision_m(self, y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    def f1_m(self, y_true, y_pred):
        precision = self.precision_m(y_true, y_pred)
        recall = self.recall_m(y_true, y_pred)
        return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
training_path = 'TrainingData.csv'
trial_path = 'TrialData.csv'
testing_path = 'EvaluationData.csv'
root_path = '/lab/dbms/fatyanosa'
datasetPath = '{}/Dataset/Suggestion Mining/'.format(root_path)
resultsPath = '{}/Server1/Suggestion Mining/Results/'.format(root_path)
testing_name = "TPOT_NGen100_NPop30_CR80_MR20"

# %%
if __name__ == '__main__':
    util = utility()
    n_run = 3
        
    # Read data
    dfTraining = util.read_CSV(datasetPath + training_path)
    
    # Read trial data
    dfTrial = util.read_CSV(datasetPath + trial_path)
    
    df = dfTraining.append(dfTrial, ignore_index=True, sort=False)
    
    texts, labels = util.get_text_label(df)
    X_train, y_train = util.get_X_Y_data(texts, labels)
    indices = np.arange(df.shape[0])
    
    idx1 = indices[0:len(dfTraining.index)]
    idx2 = indices[len(dfTraining.index):len(df.index)]
    
    # Create Testing Results
    f = open(resultsPath + testing_name + ".csv", "a+")
    f.write("i,score,time,winning_pipe\n")
    f.close()

    custom_cv = [(idx1, idx2)]
    for i in range(0, n_run):
        tpot = TPOTClassifier(generations=100, population_size=30, mutation_rate=0.2, crossover_rate=0.8, scoring='f1', verbosity=2, cv=custom_cv)
        start_time = timeit.default_timer()
        tpot.fit(X_train, y_train)

        winning_pipe=tpot.fitted_pipeline_      

        my_dict = list(tpot.evaluated_individuals_.items())

        model_scores = []
        indiv = pd.DataFrame()
        
        for model in my_dict:        
            model_name = model[0]
            model_info = model[1]
            cv_score = model[1].get('internal_cv_score')
            model_scores.append(cv_score)
            indiv = indiv.append({'generation': model[1]['generation'],'model': model_name,
                                        'cv_score': cv_score,
                                        'model_info': model_info,},
                                       ignore_index=True)

        util.append_df_to_excel(indiv, r"{}{}.xlsx".format(resultsPath, testing_name))

        tpot.export(resultsPath + testing_name + '_pipeline'+ str(i + 1) +'.py')

        elapsed = timeit.default_timer() - start_time
        # elapsed = elapsed/60
        # print('Time:', elapsed)
        # print('Score:', max(model_scores))
        # print('Winning pipeline:', winning_pipe)

        # save testing data
        f = open(resultsPath + testing_name + ".csv", 'a')
        f.write(str(i + 1)
              + ',' + str(max(model_scores))
              + ',' + str(elapsed) 
              + ',' + str(winning_pipe) 
              + '\n')
        f.close()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=3030.0, style=ProgressStyle(d…
# Generation 1 - Current best internal CV score: 0.6666666666666666
# Generation 2 - Current best internal CV score: 0.6666666666666666
# Generation 3 - Current best internal CV score: 0.6666666666666666
# Generation 4 - Current best internal CV score: 0.6666666666666666
# Generation 5 - Current best internal CV score: 0.6666666666666666
# Generation 6 - Current best internal CV score: 0.6666666666666666
# Generation 7 - Current best internal CV score: 0.6666666666666666
# Generation 8 - Current best internal CV score: 0.6666666666666666
# Generation 9 - Current best internal CV score: 0.6666666666666666
# Generation 10 - Current best internal CV score: 0.6945436002039775
# Generation 11 - Current best internal CV score: 0.6945436002039775
# Generation 12 - Current best internal CV score: 0.6945436002039775
# Generation 70 - Current best internal CV score: 0.6945436002039775
# Generation 71 - Current best internal CV score: 0.6945436002039775
# Generation 72 - Current best internal CV score: 0.6945436002039775
# Generation 73 - Current best internal CV score: 0.6945436002039775
# Generation 74 - Current best internal CV score: 0.6945436002039775
# Generation 75 - Current best internal CV score: 0.6945436002039775
# Generation 76 - Current best internal CV score: 0.6945436002039775
# Generation 77 - Current best internal CV score: 0.6945436002039775
# Generation 78 - Current best internal CV score: 0.6945436002039775
# Generation 79 - Current best internal CV score: 0.6945436002039775
# Generation 80 - Current best internal CV score: 0.6945436002039775
# Generation 81 - Current best internal CV score: 0.6945436002039775
# Generation 82 - Current best internal CV score: 0.6945436002039775
# Generation 83 - Current best internal CV score: 0.6945436002039775
# Generation 84 - Current best internal CV score: 0.6945436002039775
# Generation 85 - Current best internal CV score: 0.6945436002039775
# Generation 86 - Current best internal CV score: 0.6945436002039775
# Generation 87 - Current best internal CV score: 0.6945436002039775
# Generation 88 - Current best internal CV score: 0.6945436002039775
# Generation 89 - Current best internal CV score: 0.6945436002039775
# Generation 90 - Current best internal CV score: 0.6945436002039775
# Generation 91 - Current best internal CV score: 0.6945436002039775
# Generation 92 - Current best internal CV score: 0.6945436002039775
# Generation 93 - Current best internal CV score: 0.6945436002039775
# Generation 94 - Current best internal CV score: 0.6945436002039775
# Generation 95 - Current best internal CV score: 0.6945436002039775
# Generation 96 - Current best internal CV score: 0.6945436002039775
# Generation 97 - Current best internal CV score: 0.6945436002039775
# Generation 98 - Current best internal CV score: 0.6945436002039775
# Generation 99 - Current best internal CV score: 0.6945436002039775
# Generation 100 - Current best internal CV score: 0.6945436002039775
# Best pipeline: BernoulliNB(FeatureAgglomeration(input_matrix, affinity=euclidean, linkage=complete), alpha=0.001, fit_prior=False)
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=3030.0, style=ProgressStyle(d…
# Generation 1 - Current best internal CV score: 0.6666666666666666
# Generation 2 - Current best internal CV score: 0.6666666666666666
# Generation 3 - Current best internal CV score: 0.6666666666666666
# Generation 4 - Current best internal CV score: 0.6666666666666666
# Generation 5 - Current best internal CV score: 0.6666666666666666
# Generation 6 - Current best internal CV score: 0.6666666666666666
# Generation 7 - Current best internal CV score: 0.6666666666666666
# Generation 8 - Current best internal CV score: 0.6666666666666666
# Generation 9 - Current best internal CV score: 0.6666666666666666
# Generation 10 - Current best internal CV score: 0.6666666666666666
# Generation 11 - Current best internal CV score: 0.6666666666666666
# Generation 12 - Current best internal CV score: 0.6666666666666666
# Generation 13 - Current best internal CV score: 0.6666666666666666
# Generation 14 - Current best internal CV score: 0.6666666666666666
# Generation 15 - Current best internal CV score: 0.6666666666666666
# Generation 16 - Current best internal CV score: 0.6666666666666666
# Generation 17 - Current best internal CV score: 0.6666666666666666
# Generation 18 - Current best internal CV score: 0.6666666666666666
# Generation 19 - Current best internal CV score: 0.6666666666666666
# Generation 20 - Current best internal CV score: 0.6666666666666666
# Generation 21 - Current best internal CV score: 0.6666666666666666
# Generation 22 - Current best internal CV score: 0.6666666666666666
# Generation 23 - Current best internal CV score: 0.6666666666666666
# Generation 24 - Current best internal CV score: 0.6666666666666666
# Generation 25 - Current best internal CV score: 0.6666666666666666
# Generation 26 - Current best internal CV score: 0.6666666666666666
# Generation 27 - Current best internal CV score: 0.6666666666666666
# Generation 28 - Current best internal CV score: 0.6666666666666666
# Generation 29 - Current best internal CV score: 0.6666666666666666
# Generation 30 - Current best internal CV score: 0.6666666666666666
# Generation 31 - Current best internal CV score: 0.6666666666666666
# Generation 32 - Current best internal CV score: 0.6666666666666666
# Generation 33 - Current best internal CV score: 0.6666666666666666
# Generation 34 - Current best internal CV score: 0.6666666666666666
# Generation 35 - Current best internal CV score: 0.6666666666666666
# Generation 36 - Current best internal CV score: 0.6666666666666666
# Generation 37 - Current best internal CV score: 0.6666666666666666
# Generation 38 - Current best internal CV score: 0.6666666666666666
# Generation 39 - Current best internal CV score: 0.6666666666666666
# Generation 40 - Current best internal CV score: 0.6666666666666666
# Generation 41 - Current best internal CV score: 0.6666666666666666
# Generation 42 - Current best internal CV score: 0.6666666666666666
# Generation 43 - Current best internal CV score: 0.6666666666666666
# Generation 44 - Current best internal CV score: 0.6666666666666666
# Generation 45 - Current best internal CV score: 0.6666666666666666
# Generation 46 - Current best internal CV score: 0.6666666666666666
# Generation 47 - Current best internal CV score: 0.6666666666666666
# Generation 48 - Current best internal CV score: 0.6666666666666666
# Generation 49 - Current best internal CV score: 0.6666666666666666
# Generation 50 - Current best internal CV score: 0.6666666666666666
# Generation 51 - Current best internal CV score: 0.6666666666666666
# Generation 52 - Current best internal CV score: 0.6666666666666666
# Generation 53 - Current best internal CV score: 0.6666666666666666
# Generation 54 - Current best internal CV score: 0.6666666666666666
# Generation 55 - Current best internal CV score: 0.6666666666666666
# Generation 56 - Current best internal CV score: 0.6666666666666666
# Generation 57 - Current best internal CV score: 0.6666666666666666
# Generation 58 - Current best internal CV score: 0.6666666666666666
# Generation 59 - Current best internal CV score: 0.6666666666666666
# Generation 60 - Current best internal CV score: 0.6666666666666666
# Generation 61 - Current best internal CV score: 0.6666666666666666
# Generation 62 - Current best internal CV score: 0.6666666666666666
# Generation 63 - Current best internal CV score: 0.6666666666666666
# Generation 64 - Current best internal CV score: 0.6666666666666666
# Generation 65 - Current best internal CV score: 0.6666666666666666
# Generation 66 - Current best internal CV score: 0.6666666666666666
# Generation 67 - Current best internal CV score: 0.6666666666666666
# Generation 68 - Current best internal CV score: 0.6666666666666666
# Generation 69 - Current best internal CV score: 0.6666666666666666
# Generation 70 - Current best internal CV score: 0.6666666666666666
# Generation 71 - Current best internal CV score: 0.6666666666666666
# Generation 72 - Current best internal CV score: 0.6666666666666666
# Generation 73 - Current best internal CV score: 0.6666666666666666
# Generation 74 - Current best internal CV score: 0.6666666666666666
# Generation 75 - Current best internal CV score: 0.6666666666666666
# Generation 76 - Current best internal CV score: 0.6666666666666666
# Generation 77 - Current best internal CV score: 0.6666666666666666
# Generation 78 - Current best internal CV score: 0.6666666666666666
# Generation 79 - Current best internal CV score: 0.6666666666666666
# Generation 80 - Current best internal CV score: 0.6666666666666666
# Generation 81 - Current best internal CV score: 0.6666666666666666
# Generation 82 - Current best internal CV score: 0.6666666666666666
# Generation 83 - Current best internal CV score: 0.6666666666666666
# Generation 84 - Current best internal CV score: 0.6666666666666666
# Generation 85 - Current best internal CV score: 0.6666666666666666
# Generation 86 - Current best internal CV score: 0.6666666666666666
# Generation 87 - Current best internal CV score: 0.6666666666666666
# Generation 88 - Current best internal CV score: 0.6666666666666666
# Generation 89 - Current best internal CV score: 0.6666666666666666
# Generation 90 - Current best internal CV score: 0.6666666666666666
# Generation 91 - Current best internal CV score: 0.6666666666666666
# Generation 92 - Current best internal CV score: 0.6666666666666666
# Generation 93 - Current best internal CV score: 0.6666666666666666
# Generation 94 - Current best internal CV score: 0.6666666666666666
# Generation 95 - Current best internal CV score: 0.6666666666666666
# Generation 96 - Current best internal CV score: 0.6666666666666666
# Generation 97 - Current best internal CV score: 0.6666666666666666
# Generation 98 - Current best internal CV score: 0.6666666666666666
# Generation 99 - Current best internal CV score: 0.6666666666666666
# Generation 100 - Current best internal CV score: 0.6666666666666666
# Best pipeline: SGDClassifier(input_matrix, alpha=0.0, eta0=1.0, fit_intercept=True, l1_ratio=0.75, learning_rate=invscaling, loss=hinge, penalty=elasticnet, power_t=100.0)
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=3030.0, style=ProgressStyle(d…
# Generation 1 - Current best internal CV score: 0.6666666666666666
# Generation 2 - Current best internal CV score: 0.6666666666666666
# Generation 3 - Current best internal CV score: 0.6666666666666666
# Generation 4 - Current best internal CV score: 0.6666666666666666
# Generation 5 - Current best internal CV score: 0.6666666666666666
# Generation 6 - Current best internal CV score: 0.6666666666666666
# Generation 7 - Current best internal CV score: 0.6782419967444384
# Generation 8 - Current best internal CV score: 0.6782419967444384
# Generation 9 - Current best internal CV score: 0.6782419967444384
# Generation 10 - Current best internal CV score: 0.6782419967444384
# Generation 11 - Current best internal CV score: 0.6794462193823216
# Generation 12 - Current best internal CV score: 0.6794462193823216
# Generation 13 - Current best internal CV score: 0.6794462193823216
# Generation 14 - Current best internal CV score: 0.6806435884934179
# Generation 15 - Current best internal CV score: 0.6806435884934179
# Generation 16 - Current best internal CV score: 0.6806435884934179
# Generation 17 - Current best internal CV score: 0.6806435884934179
# Generation 18 - Current best internal CV score: 0.6806435884934179
# Generation 19 - Current best internal CV score: 0.6945436002039775
# Generation 20 - Current best internal CV score: 0.6945436002039775
# Generation 21 - Current best internal CV score: 0.6945436002039775
# Generation 22 - Current best internal CV score: 0.6945436002039775
# Generation 23 - Current best internal CV score: 0.6945436002039775
# Generation 24 - Current best internal CV score: 0.6945436002039775
# Generation 25 - Current best internal CV score: 0.6945436002039775
# Generation 26 - Current best internal CV score: 0.6945436002039775
# Generation 27 - Current best internal CV score: 0.6945436002039775
# Generation 28 - Current best internal CV score: 0.6945436002039775
# Generation 29 - Current best internal CV score: 0.6945436002039775
# Generation 30 - Current best internal CV score: 0.6945436002039775
# Generation 31 - Current best internal CV score: 0.6945436002039775
# Generation 32 - Current best internal CV score: 0.6945436002039775
# Generation 33 - Current best internal CV score: 0.6945436002039775
# Generation 34 - Current best internal CV score: 0.6945436002039775
# Generation 92 - Current best internal CV score: 0.6945436002039775
# Generation 93 - Current best internal CV score: 0.6945436002039775
# Generation 94 - Current best internal CV score: 0.6945436002039775
# Generation 95 - Current best internal CV score: 0.6945436002039775
# Generation 96 - Current best internal CV score: 0.6945436002039775
# Generation 97 - Current best internal CV score: 0.6945436002039775
# Generation 98 - Current best internal CV score: 0.6945436002039775
# Generation 99 - Current best internal CV score: 0.6945436002039775
# Generation 100 - Current best internal CV score: 0.6945436002039775
# Best pipeline: BernoulliNB(FeatureAgglomeration(input_matrix, affinity=l1, linkage=complete), alpha=0.1, fit_prior=False)

# %%
# import numpy as np
# import pandas as pd
# from sklearn.ensemble import GradientBoostingClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.naive_bayes import BernoulliNB
# from sklearn.pipeline import make_pipeline, make_union
# from sklearn.preprocessing import RobustScaler
# from sklearn.svm import LinearSVC
# from tpot.builtins import StackingEstimator
# from sklearn.preprocessing import FunctionTransformer
# from copy import copy
# import time

# # NOTE: Make sure that the outcome column is labeled 'target' in the data file
# # tpot_data = pd.read_csv('PATH/TO/DATA/FILE', sep='COLUMN_SEPARATOR', dtype=np.float64)
# # features = tpot_data.drop('target', axis=1)
# # training_features, testing_features, training_target, testing_target = \
# #             train_test_split(features, tpot_data['target'], random_state=None)
# util = utility()
# n_run = 30

# # Read data
# dfTraining = util.read_CSV(datasetPath + training_path)

# # Read trial data
# dfTest = util.read_CSV(datasetPath + testing_path)

# textsTraining, labelsTraining = util.get_text_label(dfTraining)
# textsTest, labelsTest = util.get_text_label(dfTest)

# X_train, X_test, y_train, y_test = util.get_training_test_data(
#     textsTraining, textsTest, labelsTraining, labelsTest)

# # Create Testing Results
# f = open(resultsPath + testing_name + ".csv", "w+")
# f.write("i,accuracy,precision,recall,f1Score,time\n")
# f.close()
# for i in range(0, n_run):
#     then = time.time()
#     # Average CV score on the training set was: 0.6534839924670433
#     exported_pipeline = make_pipeline(
#         make_union(
#             FunctionTransformer(copy),
#             RobustScaler()
#         ),
#         StackingEstimator(estimator=GradientBoostingClassifier(learning_rate=0.1, max_depth=2, max_features=0.6500000000000001, min_samples_leaf=17, min_samples_split=17, n_estimators=100, subsample=0.6000000000000001)),
#         StackingEstimator(estimator=LinearSVC(C=0.0001, dual=True, loss="hinge", penalty="l2", tol=0.1)),
#         StackingEstimator(estimator=GradientBoostingClassifier(learning_rate=0.1, max_depth=7, max_features=0.8500000000000001, min_samples_leaf=6, min_samples_split=17, n_estimators=100, subsample=0.9000000000000001)),
#         RobustScaler(),
#         BernoulliNB(alpha=10.0, fit_prior=False)
#     )

#     exported_pipeline.fit(X_train, y_train)
#     y_pred = exported_pipeline.predict(X_test)

#     # CNN metrics
#     accuracyScore, precisionScore, recallScore, f1Score = util.get_testing_metric(y_test, y_pred)

#     now = time.time()
#     diff = now - then
#     print(diff)
#     print(f1Score)

#     # save testing data
#     f = open(resultsPath + testing_name + ".csv", 'a')
#     f.write(str(i + 1)
#             + ',' + str(accuracyScore)
#             + ',' + str(precisionScore)
#             + ',' + str(recallScore)
#             + ',' + str(f1Score)
#             + ',' + str(diff) + '\n')
#     f.close()
